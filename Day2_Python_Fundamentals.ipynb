# %%
a=5

# %%
b=3

# %%
c=a+b

# %%
print(c)
# Out:
# 8

# %%
print(a+b)
# Out:
# 8

# %%
fullname='Fouzia'   # single or dbl quotes its completely ur choice

# %%
print(fullname)
# Out:
# Fouzia

# %%
fullname="Fouzia"

# %%
print(fullname)
# Out:
# Fouzia

# %%
#Rules for declaring the variables:

# %%
#Rule 1:

# %%
full name="Fouzia"   # u cannot have the spaces in between variables
# Out:
#   Cell In[8], line 1
#     full name="Fouzia"
#          ^
# SyntaxError: invalid syntax

# %%
#Rule 2:

# %%
1fullname="Fouzia"        #Numbers cannot be used at the beggining of the variable
# Out:
#   Cell In[9], line 1
#     1fullname="Fouzia"
#     ^
# SyntaxError: invalid decimal literal

# %%
fullname1="Fouzia"      #u can use numbers in the middle or at the end of the variables

# %%
print(fullname1)
# Out:
# Fouzia

# %%
#Rule 3:

# %%
fullname@="Fouzia"     #No special characters can be used
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fullname@="Fouzia"
#
# TypeError: unsupported operand type(s) for @=: 'str' and 'str'

# %%
full2name="Fouzia"      #u can use numbers in the middle of the variables

# %%
print(full2name)
# Out:
# Fouzia

# %%
name="fouzia tabassum"

# %%
print(name.title())    #To the correct the Format
# Out:
# Fouzia Tabassum

# %%
print(name.upper())    #For the entire letter in the Capital lettters
# Out:
# FOUZIA TABASSUM

# %%
print(name.lower())    #For the entire letter in the Lower lettters
# Out:
# fouzia tabassum
