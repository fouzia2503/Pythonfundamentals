# %%
#List Datatype:

# %%
students=['Azlan', 'Dinesh', 'Somesh', 'Davis']

# %%
print(students)
# Out:
# ['Azlan', 'Dinesh', 'Somesh', 'Davis']

# %%
type(students)
# Out:
# list

# %%
print(students[2])
# Out:
# Somesh

# %%
print(students[0])
# Out:
# Azlan

# %%
#Adding the names into the list

# %%
students.append('Kiran')

# %%
print(students)
# Out:
# ['Azlan', 'Dinesh', 'Somesh', 'Davis', 'Kiran']

# %%
students.append('Hamza')  #Adding new elements to the list

# %%
print(students)
# Out:
# ['Azlan', 'Dinesh', 'Somesh', 'Davis', 'Kiran', 'Hamza']

# %%
students [0]='sana'    #Replacing the elements

# %%
print(students)
# Out:
# ['sana', 'Dinesh', 'Somesh', 'Davis', 'Kiran', 'Hamza']

# %%
students.insert(1,'Fouz')       #Adding new elements to the list in the specific place

# %%
print(students)
# Out:
# ['sana', 'Fouz', 'Dinesh', 'Somesh', 'Davis', 'Kiran', 'Hamza']

# %%
del students[2]         #Deletion of the elements

# %%
print(students)
# Out:
# ['sana', 'Fouz', 'Somesh', 'Davis', 'Kiran', 'Hamza']
