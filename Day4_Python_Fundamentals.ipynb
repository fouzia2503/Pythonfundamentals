# %%
#   message=f"custom message {Place_holder1}{Place_holder2}-----{Place_holdern}"

# %%
firstname="fouz"

# %%
lastname="tab"

# %%
fullname= f"{firstname}{lastname}"

# %%
print(fullname)
# Out:
# fouztab

# %%
fullname= f"{firstname} {lastname}"

# %%
print(fullname)
# Out:
# fouz tab

# %%
print(fullname.title())
# Out:
# Fouz Tab

# %%
message=f"keep up the good work, {fullname.title()}"

# %%
print(message)
# Out:
# keep up the good work, Fouz Tab

# %%
#White Spaces Concept:-

# %%
print("Fav_prog:Javac++python")
# Out:
# Fav_prog:Javac++python

# %%
print("Fav_prog:\nJava\nc++\npython")
# Out:
# Fav_prog:
# Java
# c++
# python

# %%
print("Fav_prog:\n\tJava\n\tc++\n\tpython")
# Out:
# Fav_prog:
# 	Java
# 	c++
# 	python

# %%
#Eliminating the white spcaes:

# %%
name="python     "

# %%
print(name)
# Out:
# python

# %%
name2="         python"

# %%
print(name2)
# Out:
#          python

# %%
name.rstrip()
# Out:
# 'python'

# %%
name2.lstrip()
# Out:
# 'python'

# %%
print(name)
# Out:
# python

# %%
print(name2)
# Out:
#          python

# %%
name3=name2.lstrip()

# %%
print(name3)
# Out:
# python
